# %% [markdown]
# # Assignment 1
# 1. Diana Imali Luvandale: d.luvandale@alustudent.com
# 2. Heather Mataruse: h.mataruse@alustudent.com
# 3. Ian Wanjohi: i.wanjohi@alustudent.com
# 4. Lavina Kathambi: l.murithi@alustudent.com

# %% [markdown]
# # Importing All The Libraries we will need

# %%
import numpy as np
import pandas as pd
from io import StringIO
import tensorflow as tf 
import matplotlib.pyplot as plt 
from scipy import stats
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
from sklearn import datasets
import seaborn as sb

# %% [markdown]
# # DATASET
# This dataset shows data on Malaria cases in African countries from 2007-2017.
# The incidence of malaria is a variable that counts the number of malaria cases per 1000 people in areas where malaria transmission occured.
# The malaria cases reported include the number of malaria cases that have been confirmed by examination.
# In addition, the dataset includes preventive measures that have been taken to prevent malaria, such as the use of insecticide-treated bed nets,the percentage of children with fever receiving antimalarial medication, and the percentage of pregnant women receiving preventive treatment.
# The data on the incidence of malaria, malaria cases reported, and preventive treatments against malaria have been retrieved from the world bank open data source.

# %% [markdown]
# # PANDAS
# Pandas is an open-source Python package that offers various data analysis tools and can present data in a way that is appropriate for data analysis through its sequence and data frame data structures.
#
# It can be used in reading datasets as in csv files
# Pandas is built on the Numpy package.
# Its main data structure is called DataFrame.
# Dataframes allows us to store and manipulate data in row and column observations
# Enables us to view the first ten columns

# %%
df = pd.read_csv('/Users/lavinakathambi/Downloads/DatasetAfricaMalaria.csv')
df.head(10)
# Out:
#                Country Name  Year Country Code  \
# 0                   Algeria  2007          DZA
# 1                    Angola  2007          AGO
# 2                     Benin  2007          BEN
# 3                  Botswana  2007          BWA
# 4              Burkina Faso  2007          BFA
# 5                   Burundi  2007          BDI
# 6                Cabo Verde  2007          CPV
# 7                  Cameroon  2007          CMR
# 8  Central African Republic  2007          CAF
# 9                      Chad  2007          TCD
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
# 5                                             222.92
# 6                                               0.15
# ...

# %%
# dropping all null values
drop_null = df.dropna()
drop_null
# Out:
#      Country Name  Year Country Code  \
# 92        Nigeria  2008          NGA
# 97   Sierra Leone  2008          SLE
# 200       Nigeria  2010          NGA
# 205  Sierra Leone  2010          SLE
# 254       Nigeria  2011          NGA
# 362       Nigeria  2013          NGA
# 367  Sierra Leone  2013          SLE
# 470       Nigeria  2015          NGA
# 529  Sierra Leone  2016          SLE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 92                                              424.66
# 97                                              413.85
# 200                                             398.90
# 205                                             458.74
# 254                                             372.56
# 362                                             328.65
# 367                                             432.70
# 470                                             296.08
# 529                                             391.33
#
# ...

# %% [markdown]
# # SCIPY
# One of the main packages forming the SciPy stack is the SciPy library. It offers many user-friendly and useful numerical routines, such as numerical integration and optimization routines, and it is also a Python library designed to work with NumPy arrays.Scipy is also used for statistics.

# %%
#Finding the year with the most data
most_cases_reported=stats.mode(df.Year)
print(most_cases_reported)
# Out:
# ModeResult(mode=array([2007]), count=array([54]))

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a Python library used for plotting
# This python library provides objected-oriented APIs for incorporating plots into programs, which can be used in python scripts, shells, web application servers, and other graphical user interface toolkits.

# %%
#Using boxplot to check for outliers in a specific column
df.boxplot(column =['Malaria cases reported'], grid = False) 
#presence of circles indicates outliers
# Out:
# <AxesSubplot:>

# %% [markdown]
# # NUMPY
# NumPy, which is  Numerical Python, is a library of multidimensional array objects and a set of array processing routines, and it also has functions for linear algebra, Fourier transforms, and matrix domain action.
# Numpy arrays are a type of data structure that hold some benefits over Python lists such as being more compact, faster access in reading and writing items.
# For machine learning when working with predictions we can use numpy for creation of arrays
# For example when we want to predict the number of malaria cases that are going to be reported we use numpy to create two arrays for the features and label

# %%
# Creating a 1 dimension (1D) Array using a Python List
my_list = [0, 1, 2, 3, 4]
npy_my_list = np.array(my_list)
print(npy_my_list)
# Out:
# [0 1 2 3 4]

# %%
# using Numpy for prediction
predict = 'Malaria cases reported'
# features
x = np.array(df.drop([predict],1))
# labels
y = np.array(df[predict])

# %% [markdown]
# # Scikit-Learn
# Scikit-learn is a Python library that is used to implement machine learning algorithms and has different algorithms such as vector machine support, random forests, and k-neighbors, and it also supports computational and scientific libraries such as NumPy and SciPy Python.
# Scikit-learn is used for linear regression for prediction
# Splitting our data to train and test data

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size = 0.1)

# %%
# defining the model that we are going to use
model = linear_model.LinearRegression()

# %% [markdown]
# # Tensorflow
#
# TensorFlow allows developers to build graphs and frameworks for the data flow that explain how data moves through a graph or a series of nodes for processing. Each node in the graph represents a mathematical operation, and a multidimensional data array, or tensor, is each link or edge between nodes.

# %%
#converted the year column into a tensor
mytens = df['Year'].iloc[3:7].values#conversion of the column into an array
mytens = mytens.reshape(2,2)#reshaped the array to a 2D matrix
mytens = tf.convert_to_tensor(mytens)#conversion of the arra to a tensor
mytens
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[2007, 2007],
#        [2007, 2007]])>

# %%
#converted the malaria cases reported into a tensor
mytensor = df['Malaria cases reported'].iloc[3:7].values#conversion of the column into an array
mytensor = mytensor.reshape(2,2)#reshaped the array to a 2D matrix
mytensor = tf.convert_to_tensor(mytensor)#conversion of the arra to a tensor
mytensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float64, numpy=
# array([[3.900000e+02, 4.424600e+04],
#        [1.101644e+06, 1.800000e+01]])>

# %%
#addition of the tensors
tensor_a = tf.constant([[3,0]], dtype = tf.int64)
tensor_b = tf.constant([[2, 0]], dtype = tf.int64)

tensor_add = tf.add(tensor_a, tensor_b)
print(tensor_add)
# Out:
# tf.Tensor([[5 0]], shape=(1, 2), dtype=int64)

# %%
# Multiply the tensors
tensor_multiply = tf.multiply(tensor_a, tensor_b)
print(tensor_multiply)
# Out:
# tf.Tensor([[6 0]], shape=(1, 2), dtype=int64)

# %%
number_column = df.loc[:,'Year']
numbers = number_column.values
print(numbers)
# Out:
# [2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007
#  2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007
#  2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007
#  2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2007 2008 2008
#  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008
#  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008
#  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008
#  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2009 2009 2009 2009
#  2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009
#  2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009
#  2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009
#  2009 2009 2009 2009 2009 2009 2009 2009 2010 2010 2010 2010 2010 2010
#  2010 2010 2010 2010 2010 2010 2010 2010 2010 2010 2010 2010 2010 2010
# ...

# %% [markdown]
# # Keras
#
# Keras allows users to increase the image while training the model, and it is an open-source software library that provides artificial neural networks with a Python interface and functions as a TensorFlow library interface.
